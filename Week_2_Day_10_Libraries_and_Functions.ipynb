# %% [markdown]
# <a href="https://colab.research.google.com/github/manandasalim20-commits/DS_Course0_Week1_Module2_DataTypes/blob/main/Week_2_Day_10_Libraries_and_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Libraries and Functions**

# %% [markdown]
# **Functions** are the building blocks of code that perform specific tasks.
#
# **Modules** are files that contain related functions, classes, and variables.
#
# **Packages** are directories that organize related modules into a hierarchical structure.
#
# **Libraries** are a collection of packages and modules that provide a specific functionality or a set of tools.

# %% [markdown]
# ![fu.png](data:image/png;base64,...)

# %% [markdown]
# ## Example of the flow
#
# ```
#
# Library (Jewelry Brand)
# │
# ├── Package (Jewelry Store)
# │   │
# │   ├── Module (Jewelry Box)
# │   │   │
# │   │   ├── Function (Charm)
# │   │   ├── Function (Charm)
# │   │   └── Function (Charm)
# │   │
# │   ├── Module (Jewelry Box)
# │   │   ├── Function (Charm)
# │   │   └── Function (Charm)
# │   │
# │   └── Module (Jewelry Box)
# │       └── Function (Charm)
# │
# └── Package (Another Jewelry Store)
#     ├── Module (Jewelry Box)
#     │   └── Function (Charm)
#     └── Module (Jewelry Box)
#         └── Function (Charm)
#
# ```

# %% [markdown]
# # Introduction to Functions

# %% [markdown]
# ```
# def function_name(parameter1, parameter2, ...):
#     # Function body
#     # Perform operations
#     # Optional: return a value/variable
# ```
#
#
#
#
# **def:** The keyword used to define a function.
#
# **function_name**: The name you give to the function. It should be descriptive and follow Python naming conventions (lowercase with underscores).
#
# **parameters:** Optional input values that the function can accept. They are placed inside parentheses () and separated by commas.
#
# **function body:** The block of code that defines what the function does. It is indented below the function definition.
#
# **return :** An optional keyword used to specify the value/variable that the function should return. If no return statement is used, the function returns None by default.

# %%
# You define a function (e.g., greet(name) by  you name
# You assign this function to a variable (e.g., greeting_function = greet).
# The greeting_function variable now holds the memory location of the greet function.
# When you call greeting_function(), Python goes to that memory location, retrieves the instructions, and executes them.
# If the function has parameters (e.g., greet(name)), you can pass arguments (e.g., greeting_function("Alice"))
# when calling through the variable.

#define function greet
def greet(name):
    return f"Hello, {name}!"

# Assign the function to a variable
greeting_function =greet

# with a a parameter


# same as  greeting_function
greeting_function("Sam")
# Out:
# 'Hello, Sam!'

# %%
greet("Sam")
# Out:
# 'Hello, Sam!'

# %%
greeting_function("Julie")
# Out:
# 'Hello, Julie!'

# %%
def greet(name):
    return f"Hello, {name}!"

# %% [markdown]
# # `Libraries`
#
# Importing libraries means bringing the code from that package or library into your current Python script or module, making it available for use

# %%
# Step 1:  Locating package or library
import
#  looks for the specified package or library in the current directory

# if the package or library is missing and installation happens

# %%
# Step 2: Loading the package or library
# Assuming the package or the library is found
# it loads the corresponding module or package into memory

# %% [markdown]
# # Real Example
#
# Functions(Charm level)
#
# MODULE (Jewelry Box)
#
# PACKAGE (Jewelry Store)
#
# LIBRARY (Jewelry Store)

# %% [markdown]
# # FUNCTIONS (Charm Level)

# %%
# we build  basic financial calculations
# fist calculation of interest
def calculate_interest(principal,rate,time):
  return principal*rate*time

# we use the functions
interest = calculate_interest(10000,0.1,2)

# second calculation balance function
def calculate_balance(principal,interest):
  return principal+interest


# # To Do: balance
balance = calculate_balance(10000,interest)


# print(balance)
# Out:
# 2000.0

# %%
print(calculate_interest())

# %%
interest_5_year = calculate_interest(100000,0.18,5)
interest_5_year
# Out:
# 90000.0

# %%
# 3.142*r*
def calculate_area_of_circle(pie,radius_1,radius_2):
  return pie*radius_1*radius_2


area_circle = calculate_area_of_circle(3.142,7,7)
area_circle
# Out:
# 153.958

# %% [markdown]
# *   Each function does one specific task.
# *

# %% [markdown]
# # MODULE (Jewelry Box)
#
# A group related functions into a single file

# %%
# Create finance module

with open("finance.py", "w") as f:
    f.write("""
def calculate_interest(principal, rate, time):
    return principal * rate * time

def calculate_balance(principal, rate, time):
    interest = calculate_interest(principal, rate, time)
    return principal + interest

def calculate_monthly_savings(amount, months):
    return amount * months
""")

# %% [markdown]
# ## IMPORT MODULE

# %%
# Import the module
import sys
sys.path.append('/content')

import finance # I am calling the module finance we defined having the three functions

balance = finance.calculate_balance(20000, 0.1, 1)
print("Module Balance:", balance)

# %% [markdown]
# # PACKAGE (Jewelry Store)
#
# Now organize multiple modules into a folder (package).
#
# Structure
#
#
#
# ```
# package_folder/
# │
# ├── __init__.py
# ├── finance.py
# ├── members.py
# └── reports.py
# ```

# %%
import os

# Create package folder
os.makedirs("package_folder", exist_ok=True)

# Create __init__.py
# Package Recognition:
#Initializating  Code incase we run for the first time
with open("package_folder/__init__.py", "w") as f:
    f.write("")

# Create finance module inside package
with open("package_folder/finance.py", "w") as f:
    f.write("""
def calculate_interest(principal, rate, time):
    return principal * rate * time

def calculate_balance(principal, rate, time):
    interest = calculate_interest(principal, rate, time)
    return principal + interest
""")

# Create members module
with open("package_folder/members.py", "w") as f:
    f.write("""
def create_member(name, savings):
    return {"name": name, "savings": savings}

def update_savings(member, amount):
    member["savings"] += amount
    return member
""")

# %% [markdown]
# # Use Package

# %%
from package_folder import finance,members

# %%
from package_folder import finance,members
member = members.create_member("sam_jane",5000)

# TO DO: update the member saving with 3000
member_4 = members.update_savings(member,3000)
member_4
#TO DO, Calculate the balance when the rate is 0.1 and time is 1 year
# Remember the iniatial money was 5000, we have now updated the saving with 3000
# hint: we have finance and we have the calculate_balance fucntion:


# balance =

# print(member)
# print("package balance",balance)
# Out:
# {'name': 'sam_jane', 'savings': 8000}

# %% [markdown]
# # EXPAND TO LIBRARY
#
#
#
#
# ```
# lib_folfer/
# │
# ├── sacco/
# │   ├── __init__.py
# │   ├── finance.py
# │   ├── members.py
# │   ├── reports.py
# │
# ├── analytics/
#    ├── __init__.py
#    └── metrics.py
#
#
# ```

# %%
#TO DO : create the analytics file in the lib_folder
# below is your anaytics function
# def savings_growth(initial, final):
#     return ((final - initial) / initial) * 100

# Create analytics folder inside library
os.makedirs("lib_folder/analytics", exist_ok=True)

# Init file


# Create metrics module

# %% [markdown]
# # USE LIBRARY STRUCTURE

# %%
#TO DO: Import saving_growth from lib_folder

# Our initial saving was 5000, the updated saving was 8000
# What is the growth rate?
growth =

print("Savings Growth:", growth, "%")

# %% [markdown]
# Now refer to the netflix business solution

# %%
import finance as fa

# %%
import pandas  as pd

# %% [markdown]
# #**Data Science**
#
# ## **NumPy:** A library for numerical computing, providing support for large, multi-dimensional arrays and matrices.
#
# ##**Pandas:** A library for data manipulation and analysis, offering data structures like DataFrames and Series.
#
# ##**Matplotlib:** A plotting library for creating static, animated, and interactive visualizations.
#
# ## **Seaborn:** A statistical data visualization library built on top of Matplotlib.
#
# ## **Scikit-learn:** A machine learning library featuring various algorithms for classification, regression, clustering, and more.
#
# ## **TensorFlow:** An open-source library for machine learning and deep learning developed by Google.
#
# ## **PyTorch:** An open-source machine learning library developed by Facebook, known for its dynamic computational graphs.
#
# ## **NLTK (Natural Language Toolkit)**: A library for natural language processing tasks, such as tokenization, stemming, and text classification.
