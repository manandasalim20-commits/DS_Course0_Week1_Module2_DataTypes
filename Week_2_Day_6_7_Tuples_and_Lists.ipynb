# %% [markdown]
# <a href="https://colab.research.google.com/github/manandasalim20-commits/DS_Course0_Week1_Module2_DataTypes/blob/main/Week_2_Day_6_7_Tuples_and_Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.TUPLES
#
# Immutable

# %% [markdown]
# # **Creating and Using Tuples**

# %% [markdown]
# Tuples are an efficient way to **store** and **manage ordered collections** of data that should **remain unchanged**. They are created using **parentheses**, accessed via **indexing**, iterated through with **loops**, unpacked for multiple variable assignments, and used effectively in functions.

# %% [markdown]
# ## Creating a tuple
#
# To create a tuple, use parentheses () to enclose the elements you want to group together.

# %%
fruits = ("apple", "banana", "cherry")

# fruit = variable name
#variable name storing the tuple
# The tuple has three elements

# %%
# TO DO: create your tuple that shows  your (last_name, email, profession, years in that profession)
# define the tuple vraiable name as bio


bio = ("name", "email", "profession", "year in that profession")

# %% [markdown]
# ## Accessing elements in a tuple
#
# We access elements in a tuple using an index

# %%
first_fruit = fruits[0]  # first_fruit will be "apple"
second_fruit = fruits[1]  # second_fruit will be "banana"
# first_fruit: This is a variable you're creating
# fruit[O] to this variable. In our example, this would be "apple".
# [O]: This part within square brackets [] is called indexing.


# NOTE: The positive and the negaitive integer can be used to show direction

# %% [markdown]
# ### Range of Indexes

# %%
#  We use the range of indexes to access a range of elements in a tuple e.g bio([1:2])


# Assign your bio range to a variable called bio_range, what do you get?

# %% [markdown]
# ## Iterate Through Tuples

# %%
# You can use a for loop to go through each element in a tuple, such as:
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
fruits = ("apple", "banana", "cherry")
# Input your fruit
fruit = input("Enter a fruit: ")

if fruit in fruits:
    print(f"Yes, '{fruit}' is in the fruits tuple")
else:
    print("Element not found")

# %% [markdown]
# ## Unpack Tuples

# %%
colors = ("red", "green", "blue")
(color1, color2, color3) = colors

print(color1)  # Output: red
print(color2)  # Output: green
print(color3)  # Output: blue
# Out:
# red
# green
# blue

# %%
# Why are we not writting  in this format?
colors = ("red", "green", "blue")
colors = (color1, color2, color3)

print(color1)  # Output: red
print(color2)  # Output: green
print(color3)  # Output: blue

# %% [markdown]
# ## Tuple Length
#
# To determine how many elements a tuple has, use the **len()** function:

# %%
no_fruits = len(fruits)  # length will be 3
print(no_fruits)
# Out:
# 3

# %% [markdown]
# ## Tuples in functions

# %%
def get_user_info():
    name = "Alice"
    age = 30
    return (name, age)  # Returning a tuple

# break down the code step by step.
#  def get_user_info(): This line defines a function named get_user_info. Functions are reusable blocks of code that perform specific tasks.

# reusable blocks of code that perform specific tasks.
#  defines our variable names
# name = "Alice"
# age = 30


# return (name, age):
# It's used to specify the value the function will return after its execution

# %%
get_user_info()

# %% [markdown]
# # **2. LISTS**
#
#  Mutable

# %% [markdown]
# ## Creating a list
#
# Use **square brackets[]** to enclose the elements you want to group.

# %%
# Create a task list
task_list = ["Write tuples", "write lists", "Test functionality"]

# %%
fruits = ["apple", "banana", "cherry"]

# %%
# TO DO
# create your own list  called bio
#  bio = ["last name", "email", "profession", "years in that profession"]

# %% [markdown]
# ## Access Elements
#
# Use **indexing []** to retrieve elements by their position (0-based).

# %%
# Like we did in  the tuples

# %% [markdown]
# ## Modify Elements
#
# Change existing elements using their index and an assignment statement.

# %%
fruits[1] = "mango"  # Now fruits is ["apple", "mango", "cherry"]

# %%
# TO DO bio = ["last name", "email", "profession", "years in that profession"]


# TO DO  Mofify  your last name with your first name

# %% [markdown]
# ## Add Elements
#
# Append new elements to the end using append() or insert them at a specific position using insert(index, element)

# %%
fruits.append("kiwi")  # Now fruits is ["apple", "mango", "cherry", "kiwi"]
fruits
# Out:
# ['apple', 'banana', 'cherry', 'kiwi']

# %%
fruits.insert(1,"orange")
fruits
# Out:
# ['apple', 'orange', 'banana', 'cherry', 'kiwi']

# %% [markdown]
# ### Sorting elements in a list

# %%
fruits

# %%
# TO DO
# Sort your  bio's list

# %% [markdown]
# ## Remove Elements

# %% [markdown]
# Remove Specified Item

# %%
# fruits.remove("kiwi")

# %%
# TO DO
# remove email from your bio's lis

# %% [markdown]
# Remove Specified Index
#
#  use of **pop()**

# %%
fruits = ["apple", "banana", "cherry"]
fruits.pop(1)  # Removes "banana"
# Out:
# 'banana'

# %%
# TO DO
# remove index 3 from your bio's lis

# %% [markdown]
# Remove Specified Index
#
#  use of **del**

# %%
#write del followed by variable name of your then the index  e.g del fruits[0]

# %% [markdown]
# ## Iterate Through Lists
#
# Use a for loop to process each element in the list.

# %%
fruits = ["apple", "banana", "cherry"]

# Iterate through the fruits list using a for loop

for fruit in fruits:
  print(f"I like to eat {fruit}.")
# Out:
# I like to eat apple.
# I like to eat banana.
# I like to eat cherry.

# %%
# Appy the same to our bio's list, use the input function

# %% [markdown]
# ### Length of the list

# %%
# TO DO
# What is the length of your bio's list?

# %% [markdown]
# ### Extending your list with another list or a tuple

# %%
fruits = ["apple", "banana", "cherry"]
fruits2 = ["kiwi", "orange"]
fruits .extend(fruits2)
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %% [markdown]
# ## Extend Functionality
#
# Utilize list comprehensions for concise list creation and other advanced operations.

# %%
fruit.upper()
# Out:
# 'CHERRY'

# %%
# Create a new list of uppercase fruits using list comprehension

uppercase_fruits = [fruit.upper() for fruit in fruits]

print("Fruits in uppercase:", uppercase_fruits)
# Out:
# Fruits in uppercase: ['APPLE', 'BANANA', 'CHERRY']

# %%
# Try our our Bio list

# %%
# Print all items, using a while loop to go through all the index numbers

thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
# newlist = [expression for item in iterable if condition == True]

fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "c" in x]

print(newlist)
# Out:
# ['cherry']

# %%
# TO DO with your bio list

# %% [markdown]
# --------------------------END-------------------------
#
# ---
