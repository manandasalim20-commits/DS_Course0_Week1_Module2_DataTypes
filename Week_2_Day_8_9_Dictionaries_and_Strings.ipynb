# %% [markdown]
# <a href="https://colab.research.google.com/github/manandasalim20-commits/DS_Course0_Week1_Module2_DataTypes/blob/main/Week_2_Day_8_9_Dictionaries_and_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dictionaries**

# %% [markdown]
# # Syntax for a dictionary
# dict_name = {
#     "key1": "value1",
#     "key2": "value2" }
#
#  dict_name = dictionary variable name
#
#   Curly Braces {}:used to define dictionaries in Python.
#
#   Everything within these braces defines the key-value pairs that make up the dictionary.

# %%
dictionary_name = {key:value}


# # Syntax for a dictionary
# dict_name = {
#     "key1": "value1",
#     "key2": "value2"}

#  dict_name = dictionary variable name

#   Curly Braces {}:used to define dictionaries in Python.

#   Everything within these braces defines the key-value pairs that make up the dictionary.

# Key-Value Pairs:
# Key: The first part before the colon :
# keys must be unique and immutable in dictionaries

# Value: The part after the colon :represents the value associated with the corresponding key

# %% [markdown]
# Recap

# %%
# Tuple
fruits_tple= ("apple", "banana", "orange")

# list
fureits_list = ["apple", "banana", "orange"]


# Dictionary
fruits = {
  "apple": "red",
  "banana": "yellow",
  "orange": "orange"
}

# fruits - dictionary_name/variable name
# apple - key 1, red- value1
# banana - key2, yellow value2
# orange - key3, orange - value 3

# %% [markdown]
# ## Create an emppty dictionary

# %%
artist_songs = {}

# %% [markdown]
# ## Add key-value components

# %%
artist_songs = {
    "The Beatles": ["Hey Jude", "Let It Be", "Yesterday"],
    "Taylor Swift": ["Shake It Off", "Love Story", "Blank Space"],
    "Ed Sheeran": ["Perfect", "Thinking Out Loud", "Photograph"]
}

# list within  the dictonary
# 3 keys - The beatles, Taylor swift, Ed Sheeran
# Value - list, tuple, int, float, binary, string

# %% [markdown]
# Let us create ours called customers
# We have ours 4 customers
# customer_1,
# customer_2, customer_3,
# customer 4
#
# Keys in each customer
#
# name
#
# purchases[list] 4items max
#
# amount
#
# time

# %%
# write your code for the customers dictionary
Customers={"Customer_1": {"Name":"Jane", "Purchases":["Juice", "Mango", "Soda", "Shoes"], "amount":5000, "time":"10pm"}
           }

Customers
# Out:
# {'Customer_1': {'Name': 'Jane',
#   'Purchases': ['Juice', 'Mango', 'Soda', 'Shoes'],
#   'amount': 5000,
#   'time': '10pm'}}

# %%
Customers_grace={"Customer_1": ["Jane", ["Juice", "Mango", "Soda", "Shoes"], 5000, "10pm"]}
Customers_grace
# Out:
# {'Customer_1': ['Jane', ['Juice', 'Mango', 'Soda', 'Shoes'], 5000, '10pm']}

# %%
customers_name= Customers["Customer_1"]["Name"]
customers_name
# Out:
# 'Jane'

# %%
customer_grace_name= Customers_grace["Customer_1"][0]
customer_grace_name
# Out:
# 'Jane'

# %%
Customers = {
    "customer_1":{
        "name": "Cyrus",
        "purchases": ["sugar", "milk","water","biscuit"],
        "amount": 430,
        "time":"6:00PM"
        },
     "customer_2":{
        "name": "Kirui",
        "purchases": ["honey", "fruits","juice","maize"],
        "amount": 600,
        "time":"6:00PM",
        }

}
Customers
# Out:
# {'customer_1': {'name': 'Cyrus',
#   'purchases': ['sugar', 'milk', 'water', 'biscuit'],
#   'amount': 430,
#   'time': '6:00PM'},
#  'customer_2': {'name': 'Kirui',
#   'purchases': ['honey', 'fruits', 'juice', 'maize'],
#   'amount': 600,
#   'time': '6:00PM'}}

# %%
# Access customer_1 info
Customers['customer_1']
# Out:
# {'name': 'Cyrus',
#  'purchases': ['sugar', 'milk', 'water', 'biscuit'],
#  'amount': 430,
#  'time': '6:00PM'}

# %%
# Access customer_1 name
Customers['customer_1']['name']
# Out:
# 'Cyrus'

# %%
# Access customer 1 purchases
Customers['customer_1']['purchases']
# Out:
# ['sugar', 'milk', 'water', 'biscuit']

# %%
# Access one item purchased by customer
Customers['customer_1']['purchases'][2]
# Out:
# 'water'

# %% [markdown]
# ## Accessing data in a dictionary

# %%
# example of the artist_songs disctionary
beatles_song  =
# Out:
# {'name': 'Alice', 'purchases': ['Laptop', 'Headphones']}

# %%
beatles_songs = artist_songs["The Beatles"]

print(beatles_songs)  # Output: ["Hey Jude", "Let It Be", "Yesterday"]
# Out:
# ['Hey Jude', 'Let It Be', 'Yesterday']

# %%
# Let us use get customer_3 information
customer_3 info =

# %% [markdown]
# ## Iterating through our dictionary

# %%
for song in beatles_songs:

    print(f"- {song}")
# Out:
# - Hey Jude
# - Let It Be
# - Yesterday

# %%
# Try with customer_4

# %%
Customers['customer_1']['name'] =

# %%
## Adding a new customer named customer_5 in the same format as the data of the 4 customers
Customers["customer_5"] = {"name": "__________", "purchases": ["____","______","___"],"time":"____--"}
Customers
# Out:
# {'customer_1': {'name': 'Cyrus',
#   'purchases': ['sugar', 'milk', 'water', 'biscuit'],
#   'amount': 430,
#   'time': '6:00PM'},
#  'customer_2': {'name': 'Kirui',
#   'purchases': ['honey', 'fruits', 'juice', 'maize'],
#   'amount': 600,
#   'time': '6:00PM'},
#  'customer_5': {'name': '__________',
#   'purchases': ['____', '______', '___'],
#   'time': '____--'}}

# %% [markdown]
# ## Updating a dictionary

# %%
# Customer_2 noticed her order was wrong in as much as the  price was the same, update her purchase records
# variable_name["key"]["value"][index].append(_________)  updatinf a list
# variable_name["key"]["value"][index] = "____"  no list

# %% [markdown]
# Check canvas for more examples

# %% [markdown]
# # **Strings**
#
#
# Use single or double quotes to enclose the text. **" " , ' '**
#
#
# Optionally, use triple quotes for multiline strings.

# %%
# Example  of  Spring

"Sam Jane"

'Sam Jane'

# %% [markdown]
# ## Accessing Chartacters in a string
#
# Use the square bracket **[]**

# %%
sam = "Sam_Jane"
sam[2]
# Out:
# 'm'

# %%
dsf_pt15 = 'students_email'
dsf_pt15[0:7]
# Out:
# 'student'

# %%
# Write your email as a string

# %% [markdown]
# <!-- Slicing strings -->

# %% [markdown]
# ## Slicing Strings

# %%
sam[4:8]
# Out:
# 'Jane'

# %% [markdown]
# ## Concantenation
#
# We use **+** Joining two strings together to create a longer one

# %%
section1 = "ian.sam"
section2 = "@students.moringaschool.com"

email = section1 +section2
email
# Out:
# 'ian.sam@students.moringaschool.com'

# %%
# perdsonal names
# last_name
# first_name
last_name = 'Jane'
first_anem = 'Samwel'
personal_names = last_name + first_anem
personal_names
# Out:
# 'Samwel'

# %% [markdown]
# ## String  formatting (f-strings)
#
#
# Allow embedding expressions directly inside string literals using {}.

# %%
# # Example
student_number = 95
print(f" The number of student in dsf-pt15 is: {student_number}")

# %%
#Access  items that were bought by customer_2

print(f"There were four items that were bought by customer_2 and includes: {Customers['customer_2']['purchases']}")
# Out:
# There were four items that were bought by customer_2 and includes: ['honey', 'fruits', 'juice', 'maize']

# %% [markdown]
# ## String methods
#
# upper()
#
# lower()
#
# capitalize()
#
# find()
#
# replace()

# %% [markdown]
# # Checking string membership

# %%
# verify email
moringa_email = "samwel.jane@moringaschool.com"

# %%
# email = input("Enter email: ")

# if "@" in email and "." in email:
#     print("Valid email format")
# else:
#     print("Invalid email")

# %% [markdown]
# Iteration

# %%
for char in string:
    do something with char

# char → each bead (character)

# string → the necklace

# %% [markdown]
# example

# %%
name = "banana"
count_a = 0

for i in name:
    if i == "a":
        count_a += 1

print(f"Number of 'a's: {count_a}")
# Out:
# Number of 'a's: 3
